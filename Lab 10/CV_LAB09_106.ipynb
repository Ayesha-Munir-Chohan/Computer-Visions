# %%
# Code Example: Real-Time Object Detection for Smart Traffic Surveillance System
from ultralytics import YOLO 
import cv2 
import matplotlib.pyplot as plt 
model = YOLO('yolov8n.pt') 
image_path = "D:/23108106/A19.jpg" 
image = cv2.imread(image_path) 
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
results = model(image_path) 
results[0].plot()
plt.figure(figsize=(12, 8)) 
plt.imshow(results[0].plot()[..., ::-1]) 
plt.axis('off') 
plt.title("Object Detection using YOLOv8") 
plt.show()
# Out:
# image 1/1 D:\23108106\A19.jpg: 480x640 8 cars, 1 bus, 1 truck, 104.8ms
# Speed: 40.1ms preprocess, 104.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Case Study 1: Real-Time Surveillance Analysis in Public Parks
import cv2 
from ultralytics import YOLO 
model = YOLO("yolov8n.pt") 
results = model("D:/23108106/A16.jpg") 
import matplotlib.pyplot as plt 
import cv2 
img = results[0].plot()
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
plt.imshow(img_rgb)
plt.axis("off") 
plt.show()
# Out:
# image 1/1 D:\23108106\A16.jpg: 448x640 1 person, 100.6ms
# Speed: 4.1ms preprocess, 100.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Object Detection Using SSD
from ultralytics import YOLO
import cv2
from moviepy.editor import VideoFileClip
model = YOLO("yolov8n.pt")
video_path = "D:/23108106/Lecture A.mp4"
cap = cv2.VideoCapture(video_path)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)
out = cv2.VideoWriter(
    "output.mp4",
    cv2.VideoWriter_fourcc(*'mp4v'),
    5,
    (640, 640)
)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.resize(frame, (640, 640))
    results = model.predict(frame, imgsz=640, conf=0.5, verbose=False)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)
cap.release()
out.release()
print("Video saved as output.mp4")
clip = VideoFileClip("output.mp4")
clip.write_gif("output.gif")
print("GIF saved as output.gif")
# Out:
# Video saved as output.mp4
# MoviePy - Building file output.gif with imageio.
# GIF saved as output.gif

# %%
# Case Study 2: Retail Checkout Automation
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO('yolov8n.pt')
image_path = "D:/23108106/A22.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated_img = results[0].plot()
img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 8))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Smart Retail Checkout System using YOLOv8")
plt.show()
# Out:
# image 1/1 D:\23108106\A22.jpg: 416x640 5 persons, 1 tie, 1 tv, 93.5ms
# Speed: 3.8ms preprocess, 93.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)

# %%
# Case Study 1: Smart Classroom Monitoring
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/23108106/A22.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Smart Classroom Monitoring")
plt.show()
# Out:
# image 1/1 D:\23108106\A22.jpg: 416x640 5 persons, 1 tie, 1 tv, 67.3ms
# Speed: 2.8ms preprocess, 67.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)

# %%
#Case Study 2: Smart Parking Surveillance System
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/23108106/A19.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Smart Parking Surveillance")
plt.show()
# Out:
# image 1/1 D:\23108106\A19.jpg: 480x640 8 cars, 1 bus, 1 truck, 94.8ms
# Speed: 4.1ms preprocess, 94.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Case Study 3: Wildlife Conservation Monitoring
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/23108106/A29.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Wildlife Conservation Monitoring")
plt.show()
# Out:
# image 1/1 D:\23108106\A29.jpg: 640x480 1 cat, 1 bed, 119.1ms
# Speed: 4.8ms preprocess, 119.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)

# %%
# Case Study 4: Industrial Defect Detection System
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/23108106/A21.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Industrial Defect Detection")
plt.show()
# Out:
# image 1/1 D:\23108106\A21.jpg: 448x640 (no detections), 64.3ms
# Speed: 3.2ms preprocess, 64.3ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Case Study 5: Retail Store Analytics with Shelf Monitoring
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from collections import Counter
model = YOLO("yolov8n.pt")
image_path = "D:/23108106/A9.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
items = []
for r in results:
    for box in r.boxes:
        cls = int(box.cls[0])
        items.append(model.names[cls])
count = Counter(items)
print("Shelf Inventory:")
for item, qty in count.items():
    print(item, ":", qty)
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Retail Shelf Monitoring")
plt.show()
# Out:
# image 1/1 D:\23108106\A9.jpg: 480x640 (no detections), 83.5ms
# Speed: 3.8ms preprocess, 83.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Shelf Inventory:
